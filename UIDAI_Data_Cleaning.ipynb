# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json

# %%
pip install pandas openpyxl

# %%
# Adjust paths accordingly
df1 = pd.read_csv("api_data_aadhar_biometric_0_500000.csv")
df2 = pd.read_csv("api_data_aadhar_biometric_500000_1000000.csv")
df3 = pd.read_csv("api_data_aadhar_biometric_1000000_1500000.csv")
df4 = pd.read_csv("api_data_aadhar_biometric_1500000_1861108.csv")

# Combine all
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#                date                        state                  district  \
# 0        01-09-2025  Andaman and Nicobar Islands                  Andamans
# 1        01-09-2025  Andaman and Nicobar Islands  North And Middle Andaman
# 2        01-09-2025  Andaman and Nicobar Islands             South Andaman
# 3        01-09-2025  Andaman and Nicobar Islands             South Andaman
# 4        12-09-2025  Andaman and Nicobar Islands             South Andaman
# ...             ...                          ...                       ...
# 1861103  29-12-2025                  West Bengal            Uttar Dinajpur
# 1861104  29-12-2025                  West Bengal            Uttar Dinajpur
# 1861105  29-12-2025                  West Bengal            West Midnapore
# 1861106  29-12-2025                  West Bengal            West Midnapore
# 1861107  29-12-2025                  West Bengal            West Midnapore
#
#          pincode  bio_age_5_17  bio_age_17_
# ...

# %%
# Mapping table exported from Excel
mapping = pd.read_excel("District_Mapping.xlsx")  # Make sure table has From_District & To_District columns

# Lowercase and strip spaces for safe matching
mapping['From_District'] = mapping['From_District'].str.lower().str.strip()
mapping['To_District'] = mapping['To_District'].str.lower().str.strip()

# %%
df['District_clean'] = df['district'].str.lower().str.strip()

# %%
# Convert mapping table to dict
district_dict = dict(zip(mapping['From_District'], mapping['To_District']))

# %%
# Replace using mapping
df['Final_District'] = df['District_clean'].map(district_dict)

# If no match, keep original
df['Final_District'] = df['Final_District'].fillna(df['district'])

# %%
df['Final_District'] = df['Final_District'].str.title()

# %%
df.head()
# Out:
#          date                        state                  district  pincode  \
# 0  01-09-2025  Andaman and Nicobar Islands                  Andamans   744103
# 1  01-09-2025  Andaman and Nicobar Islands  North And Middle Andaman   744205
# 2  01-09-2025  Andaman and Nicobar Islands             South Andaman   744101
# 3  01-09-2025  Andaman and Nicobar Islands             South Andaman   744206
# 4  12-09-2025  Andaman and Nicobar Islands             South Andaman   744105
#
#    bio_age_5_17  bio_age_17_            District_clean  \
# 0             2            6                  andamans
# 1             6            4  north and middle andaman
# 2             5            5             south andaman
# 3             9            4             south andaman
# 4             9            5             south andaman
#
#              Final_District
# 0                  Andamans
# 1  North And Middle Andaman
# 2             South Andaman
# 3             South Andaman
# ...

# %%
df['Final_District'] = df['Final_District'].str.replace('*', '', regex=False)

# %%
df_sorted = df.sort_values(by='Final_District').reset_index(drop=True)

# %%
display(df_sorted['Final_District'].unique())
# Out:
# array(['?', 'Adilabad', 'Agarmalwa', 'Agra', 'Ahilyanagar', 'Ahmedabad',
#        'Ahmednagar', 'Aizawl', 'Ajmer', 'Akera', 'Akola', 'Alappuzha',
#        'Aligarh', 'Alipurduar', 'Alirajpur', 'Alluri Sitharama Raju',
#        'Almora', 'Alwar', 'Ambala', 'Ambedkar Nagar', 'Amethi',
#        'Amravati', 'Amreli', 'Amritsar', 'Amroha', 'Anakapalli', 'Anand',
#        'Anantapur', 'Ananthapuramu', 'Anantnag', 'Anantpur', 'Andamans',
#        'Anjaw', 'Annamayya', 'Anugul', 'Anuppur', 'Araria', 'Ariyalur',
#        'Arvalli', 'Arwal', 'Ashoknagar', 'Auraiya', 'Aurangabad',
#        'Aurangabad(Bh)', 'Ayodhya', 'Azamgarh', 'Bagalkot', 'Bageshwar',
#        'Baghpat', 'Bahraich', 'Bajali', 'Baksa', 'Balaghat', 'Balangir',
#        'Baleshwar', 'Baleswar', 'Ballari', 'Ballia', 'Bally Jagachha',
#        'Balod', 'Baloda Bazar', 'Balotra', 'Balrampur', 'Banas Kantha',
#        'Banaskantha', 'Banda', 'Bandipora', 'Bangalore Rural', 'Banka',
# ...

# %%
df_sorted['Final_District'].unique().size
# Out:
# 882

# %%
df_sorted['state'].unique()
# Out:
# array(['Jammu and Kashmir', 'Telangana', 'Andhra Pradesh',
#        'Madhya Pradesh', 'Uttar Pradesh', 'Maharashtra', 'Gujarat',
#        'Mizoram', 'Rajasthan', 'Haryana', 'Kerala', 'West Bengal',
#        'Uttarakhand', 'Punjab', 'Jammu & Kashmir',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Arunachal Pradesh', 'Odisha', 'Orissa', 'Bihar', 'Tamil Nadu',
#        'Karnataka', 'Assam', 'Chhattisgarh', 'Goa', 'Himachal Pradesh',
#        'Manipur', 'Jharkhand', 'Delhi', 'Chandigarh', 'Tamilnadu',
#        'andhra pradesh', 'Nagaland', 'Pondicherry',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Dadra & Nagar Haveli',
#        'Dadra and Nagar Haveli', 'Daman & Diu', 'Daman and Diu',
#        'Tripura', 'Sikkim', 'Meghalaya', 'odisha', 'Uttaranchal',
#        'West  Bengal', 'West bengal', 'West Bangal', 'Westbengal',
#        'WEST BENGAL', 'WESTBENGAL', 'Puducherry', 'Ladakh', 'Lakshadweep',
#        'ODISHA', 'Chhatisgarh'], dtype=object)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('&', 'and', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Orissa', 'Odisha', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Chhatisgarh', 'Chhattisgarh', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('odisha', 'Odisha', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('ODISHA', 'Odisha', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('andhra pradesh', 'Andhra Pradesh', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('andhra pradesh', 'Andhra Pradesh', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('West bengal', 'West Bengal', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('West  Bengal', 'West Bengal', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('West Bangal', 'West Bengal', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Westbengal', 'West Bengal', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('WEST BENGAL', 'West Bengal', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('WESTBENGAL', 'West Bengal', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Dadra and Nagar Haveli', 'Daman and Diu', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Daman and Diu','Dadra and Nagar Haveli and Daman and Diu', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Uttaranchal', 'Uttarakhand', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Pondicherry', 'Puducherry', regex=False)

# %%
df_sorted['state'] = df_sorted['state'].str.replace('Tamilnadu', 'Tamil Nadu', regex=False)

# %%
# df_sorted.loc[(df_sorted['state']=='Sikkim') & (df_sorted['Final_District']=='West')]['Final_District'] = 'West Sikkim'

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Ahmednagar', 'Ahilyanagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Anantapur', 'Ananthapuramu', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Anantpur', 'Ananthapuramu', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Aurangabad(Bh)', 'Aurangabad', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Baleswar', 'Baleshwar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Banas Kantha', 'Banaskantha', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Bangalore', 'Bengaluru', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Bheed', 'Beed', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Bokaro ', 'Bokaro', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chamarajanagar ', 'Chamrajanagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chamarajanagar', 'Chamrajanagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chandauli ', 'Chandauli', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chatrapati Sambhaji Nagar ', 'Chhatrapati Sambhajinagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chatrapati Sambhaji Nagar ', 'Chhatrapati Sambhajinagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Bardhaman', 'Barddhaman', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chikmagalur', 'Chikkamagaluru', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chittaurgarh', 'Chittorgarh', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Deeg\xa0', 'Deeg', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Dhalai  ', 'Dhalai', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Dhaulpur  ', 'Dholpur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('East Midnapur', 'East Midnapore', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Gadag ', 'Gadag', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Garhwa ', 'Garhwa', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Gautam Buddha Nagar ', 'Gautam Buddha Nagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Gondiya', 'Gondia', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Harda ', 'Harda', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Hawrah', 'Howrah', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Hingoli ', 'Hingoli', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Jajpur', 'Jajapur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Jalor', 'Jalore', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Janjgir - Champa', 'Janjgir-Champa', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Janjgir Champa', 'Janjgir-Champa', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Jhunjhunun', 'Jhunjhunu', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('K. V. Rangareddy', 'K.V. Rangareddy', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('K.V.Rangareddy', 'K.V. Rangareddy', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Khorda', 'Khordha', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Khordha  ', 'Khordha', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Kushinagar ', 'Kushinagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Lahul And Spiti', 'Lahaul And Spiti', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Leh (Ladakh)', 'Leh', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Mammit', 'Mamit', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Manendragarhchirmiribharatpur', 'Manendragarh–Chirmiri–Bharatpur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Medchal?Malkajgiri', 'Medchal-Malkajgiri', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Medchal−Malkajgiri', 'Medchal-Malkajgiri', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Mohalla-Manpur-Ambagarh Chowki', 'Mohla-Manpur-Ambagarh Chouki', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Muktsar', 'Sri Mukstar Sahib', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Nandurbar ', 'Nandurbar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('North Twenty Four Parganas', 'North 24 Parganas', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Paschim Medinipur', 'Paschim Midnapore', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Purba Medinipur', 'Purba Midnapore', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Rangareddy', 'K. V. Rangareddy', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Saiha', 'Siaha', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Sant Ravidas Nagar', 'Bhadohi', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Sant Ravidas Nagar Bhadohi', 'Bhadohi', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Sas Nagar', 'S.A.S. Nagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Sonapur', 'Sonepur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('South 24 Pargana', 'South 24 Parganas', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Subarnapur', 'Sonepur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Sundergarh', 'Sundargarh', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Udupi ', 'Udupi', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Villupuram ', 'Viluppuram', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Washim ', 'Washim', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('West Medinipur', 'West Midnapore', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Washim ', 'Washim', regex=False)

# %%
df_sorted['Final_District'].unique().size
# Out:
# 834

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('South 24 Parganass', 'South 24 Parganas', regex=False)

# %%
districts_map = {
    'North': 'North Sikkim',
    'South': 'South Sikkim',
    'East': 'East Sikkim',
    'West': 'West Sikkim'
}

for old_district, new_district in districts_map.items():
    df_sorted.loc[
        (df_sorted['state'] == 'Sikkim') & (df_sorted['Final_District'] == old_district),
        'Final_District'
    ] = new_district

# %%
print("Unique districts in Sikkim after replacement:")
display(df_sorted[df_sorted['state'] == 'Sikkim']['Final_District'].unique())
# Out:
# Unique districts in Sikkim after replacement:
# array(['East Sikkim', 'Namchi', 'North Sikkim', 'South Sikkim',
#        'West Sikkim'], dtype=object)

# %%
districts_map = {
    'North East': 'North East Delhi'
}

for old_district, new_district in districts_map.items():
    df_sorted.loc[
        (df_sorted['state'] == 'Delhi') & (df_sorted['Final_District'] == old_district),
        'Final_District'
    ] = new_district

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Baudh', 'Boudh', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Chatrapati Sambhaji Nagar', 'Chhatrapati Sambhajinagar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Dadra And Nagar Haveli', 'Dadra and Nagar Haveli', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Dakshin Bastar Dantewada', 'Dantewada', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Debagarh', 'Deogarh', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Dhaulpur', 'Dholpur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Gondia ', 'Gondia', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Haveri ', 'Haveri', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Jaloree', 'Jalore', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Jagatsinghpur', 'Jagatsinghapur', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('K.V. K. V. Rangareddy', 'K.V. Rangareddy', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Karimganj', 'Sribhumi', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Mahoba ', 'Mahoba', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Mumbai( Sub Urban )', 'Mumbai Suburban', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Punch', 'Poonch', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Purlia', 'Purulia', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Bhadohi Bhadohi', 'Bhadohi', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('South Twenty Four Parganas', 'South 24 Parganas', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Sri Sri Mukstar Sahib Sahib', 'Sri Mukstar Sahib', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Villupuram', 'Viluppuram', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Khandwa', 'East Nimar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Khargone', 'West Nimar', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('Raigarh(Mh)', 'Raigad', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('?', 'Unknown', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('S.A.S Nagar(Mohali)', 'S.A.S. Nagar (Mohali)', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('K. V. Rangareddy', 'K.V. Rangareddy', regex=False)

# %%
df_sorted['Final_District'] = df_sorted['Final_District'].str.replace('', '', regex=False)

# %%
df_sorted['Final_District'].unique().size
# Out:
# 805

# %%
df_sorted = df_sorted.drop(columns=['district', 'District_clean'])
display(df_sorted.head())
# Out:
#          date              state  pincode  bio_age_5_17  bio_age_17_  \
# 0  17-11-2025  Jammu and Kashmir   181206             0            1
# 1  14-12-2025          Telangana   504310             1            0
# 2  14-12-2025          Telangana   504309             3            2
# 3  14-12-2025          Telangana   504299             1            0
# 4  14-12-2025          Telangana   504295             0            1
#
#   Final_District
# 0        Unknown
# 1       Adilabad
# 2       Adilabad
# 3       Adilabad
# 4       Adilabad

# %%
df_sorted = df_sorted.rename(columns={'Final_District': 'District'})
display(df_sorted.head())
# Out:
#          date              state  pincode  bio_age_5_17  bio_age_17_  District
# 0  17-11-2025  Jammu and Kashmir   181206             0            1   Unknown
# 1  14-12-2025          Telangana   504310             1            0  Adilabad
# 2  14-12-2025          Telangana   504309             3            2  Adilabad
# 3  14-12-2025          Telangana   504299             1            0  Adilabad
# 4  14-12-2025          Telangana   504295             0            1  Adilabad

# %% [markdown]
# #### Adding Columns

# %%
df_sorted['total_updates'] = df_sorted['bio_age_5_17'] + df_sorted['bio_age_17_']
# display(df_sorted.head())

# %%
df_sorted['child_ratio'] = df_sorted.apply(lambda row: round(row['bio_age_5_17'] / row['total_updates'], 4) if row['total_updates'] != 0 else 0.0, axis=1)

# %%
df_sorted['adult_ratio'] = df_sorted.apply(lambda row: round(row['bio_age_17_'] / row['total_updates'], 4) if row['total_updates'] != 0 else 0.0, axis=1)
display(df_sorted.head())
# Out:
#          date              state  pincode  bio_age_5_17  bio_age_17_  \
# 0  17-11-2025  Jammu and Kashmir   181206             0            1
# 1  14-12-2025          Telangana   504310             1            0
# 2  14-12-2025          Telangana   504309             3            2
# 3  14-12-2025          Telangana   504299             1            0
# 4  14-12-2025          Telangana   504295             0            1
#
#    District  total_updates  child_ratio  adult_ratio
# 0   Unknown              1          0.0          1.0
# 1  Adilabad              1          1.0          0.0
# 2  Adilabad              5          0.6          0.4
# 3  Adilabad              1          1.0          0.0
# 4  Adilabad              1          0.0          1.0

# %%
df_sorted['state'].unique()
# Out:
# array(['Jammu and Kashmir', 'Telangana', 'Andhra Pradesh',
#        'Madhya Pradesh', 'Uttar Pradesh', 'Maharashtra', 'Gujarat',
#        'Mizoram', 'Rajasthan', 'Haryana', 'Kerala', 'West Bengal',
#        'Uttarakhand', 'Punjab', 'Andaman and Nicobar Islands',
#        'Arunachal Pradesh', 'Odisha', 'Bihar', 'Tamil Nadu', 'Karnataka',
#        'Assam', 'Chhattisgarh', 'Goa', 'Himachal Pradesh', 'Manipur',
#        'Jharkhand', 'Delhi', 'Chandigarh', 'Nagaland', 'Puducherry',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Tripura', 'Sikkim',
#        'Meghalaya', 'Ladakh', 'Lakshadweep'], dtype=object)

# %%
df_sorted.columns
# Out:
# Index(['date', 'state', 'pincode', 'bio_age_5_17', 'bio_age_17_', 'District',
#        'total_updates', 'child_ratio', 'adult_ratio'],
#       dtype='object')

# %%
df_sorted = df_sorted.rename(columns={'state': 'State','date':'Date of Updation','pincode':'Pincode',
                                      'bio_age_5_17':'Bio_age_5_17','bio_age_17':'Bio_age_17_',
                                      'total_updates':'Total_Updates','child_ratio':'Child_Ratio',
                                      'adult_ratio':'Adult_Ratio'})

# %%
df_sorted.to_csv('UIDAI_Bio_Cleaned_Data.csv', index=False)

# %% [markdown]
# ## Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams["figure.figsize"] = (10,5)
sns.set_style("whitegrid")

# %%
data=pd.read_csv('UIDAI_Bio_Cleaned_Data.csv')

# %%
data.shape
# Out:
# (1861108, 9)

# %%
data.columns
# Out:
# Index(['Date of Updation', 'State', 'Pincode', 'Bio_age_5_17', 'bio_age_17_',
#        'District', 'Total_Updates', 'Child_Ratio', 'Adult_Ratio'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1861108 entries, 0 to 1861107
# Data columns (total 9 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Date of Updation  object
#  1   State             object
#  2   Pincode           int64
#  3   Bio_age_5_17      int64
#  4   bio_age_17_       int64
#  5   District          object
#  6   Total_Updates     int64
#  7   Child_Ratio       float64
#  8   Adult_Ratio       float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 127.8+ MB

# %%
selected_columns = ['Bio_age_5_17', 'bio_age_17_', 'Total_Updates', 'Child_Ratio', 'Adult_Ratio']
display(data[selected_columns].describe())
# Out:
#        Bio_age_5_17   bio_age_17_  Total_Updates   Child_Ratio   Adult_Ratio
# count  1.861108e+06  1.861108e+06   1.861108e+06  1.861108e+06  1.861108e+06
# mean   1.839058e+01  1.909413e+01   3.748471e+01  4.728444e-01  5.271492e-01
# std    8.370421e+01  8.806502e+01   1.623302e+02  3.038688e-01  3.038694e-01
# min    0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  1.000000e+00   3.000000e+00  2.500000e-01  3.333000e-01
# 50%    3.000000e+00  4.000000e+00   8.000000e+00  5.000000e-01  5.000000e-01
# 75%    1.100000e+01  1.000000e+01   2.200000e+01  6.667000e-01  7.500000e-01
# max    8.002000e+03  7.625000e+03   1.338100e+04  1.000000e+00  1.000000e+00

# %%
data.isna().sum()
# Out:
# Date of Updation    0
# State               0
# Pincode             0
# Bio_age_5_17        0
# bio_age_17_         0
# District            0
# Total_Updates       0
# Child_Ratio         0
# Adult_Ratio         0
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
data["Date of Updation"] = pd.to_datetime(data["Date of Updation"], dayfirst=True)

# %%
data["Year"] = data["Date of Updation"].dt.year
data["Month"] = data["Date of Updation"].dt.month
data["Month_Year"] = data["Date of Updation"].dt.to_period("M")

# %%
data.head()
# Out:
#   Date of Updation              State  Pincode  Bio_age_5_17  bio_age_17_  \
# 0       2025-11-17  Jammu and Kashmir   181206             0            1
# 1       2025-12-14          Telangana   504310             1            0
# 2       2025-12-14          Telangana   504309             3            2
# 3       2025-12-14          Telangana   504299             1            0
# 4       2025-12-14          Telangana   504295             0            1
#
#    District  Total_Updates  Child_Ratio  Adult_Ratio  Year  Month Month_Year
# 0   Unknown              1          0.0          1.0  2025     11    2025-11
# 1  Adilabad              1          1.0          0.0  2025     12    2025-12
# 2  Adilabad              5          0.6          0.4  2025     12    2025-12
# 3  Adilabad              1          1.0          0.0  2025     12    2025-12
# 4  Adilabad              1          0.0          1.0  2025     12    2025-12
